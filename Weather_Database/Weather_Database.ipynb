# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import Citipy.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 723

# %%
# Import the requests library.
import requests
import time
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | frameries
# Processing Record 4 of Set 1 | hualmay
# Processing Record 5 of Set 1 | mykolayivka
# Processing Record 6 of Set 1 | tasiilaq
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | mabaruma
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | pevek
# Processing Record 14 of Set 1 | moussoro
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | singaparna
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | tiarei
# Processing Record 19 of Set 1 | ponta do sol
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | jijiga
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | san policarpo
# Processing Record 24 of Set 1 | alofi
# Processing Record 25 of Set 1 | husavik
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | chuy
# Processing Record 29 of Set 1 | oktyabrskoye
# Processing Record 30 of Set 1 | vallenar
# Processing Record 31 of Set 1 | challans
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | sile
# Processing Record 35 of Set 1 | havoysund
# Processing Record 36 of Set 1 | cabo san lucas
# Processing Record 37 of Set 1 | kiama
# Processing Record 38 of Set 1 | homer
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | houma
# Processing Record 41 of Set 1 | palana
# Processing Record 42 of Set 1 | haapiti
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | saint-philippe
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | te anau
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | okha
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | goundi
# Processing Record 2 of Set 2 | salalah
# Processing Record 3 of Set 2 | yar-sale
# Processing Record 4 of Set 2 | ancud
# Processing Record 5 of Set 2 | kiruna
# Processing Record 6 of Set 2 | baillif
# Processing Record 7 of Set 2 | maniwaki
# Processing Record 8 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | ballina
# Processing Record 12 of Set 2 | faya
# Processing Record 13 of Set 2 | dingle
# Processing Record 14 of Set 2 | nome
# Processing Record 15 of Set 2 | shimoda
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | macau
# Processing Record 18 of Set 2 | kemijarvi
# Processing Record 19 of Set 2 | lavrentiya
# Processing Record 20 of Set 2 | san andres
# Processing Record 21 of Set 2 | karasjok
# Processing Record 22 of Set 2 | sao desiderio
# Processing Record 23 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 24 of Set 2 | rocha
# Processing Record 25 of Set 2 | beringovskiy
# Processing Record 26 of Set 2 | morden
# Processing Record 27 of Set 2 | mehamn
# Processing Record 28 of Set 2 | esmeraldas
# Processing Record 29 of Set 2 | blagodatnoye
# Processing Record 30 of Set 2 | bagar
# Processing Record 31 of Set 2 | kodinsk
# Processing Record 32 of Set 2 | kahului
# Processing Record 33 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | palaikastron
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | kizilskoye
# Processing Record 39 of Set 2 | klaksvik
# Processing Record 40 of Set 2 | nova olinda do norte
# Processing Record 41 of Set 2 | manado
# Processing Record 42 of Set 2 | severo-kurilsk
# Processing Record 43 of Set 2 | puerto del rosario
# Processing Record 44 of Set 2 | jieshi
# Processing Record 45 of Set 2 | cayenne
# Processing Record 46 of Set 2 | sarangani
# Processing Record 47 of Set 2 | saint-augustin
# Processing Record 48 of Set 2 | micheweni
# Processing Record 49 of Set 2 | meulaboh
# Processing Record 50 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 3 | munak
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | nyaunglebin
# Processing Record 4 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 3 | gumushane
# City not found. Skipping...
# Processing Record 6 of Set 3 | sinnamary
# Processing Record 7 of Set 3 | mubi
# Processing Record 8 of Set 3 | hithadhoo
# Processing Record 9 of Set 3 | vaini
# Processing Record 10 of Set 3 | sesheke
# Processing Record 11 of Set 3 | tsumeb
# Processing Record 12 of Set 3 | kodiak
# Processing Record 13 of Set 3 | fukue
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | guaruja
# Processing Record 19 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 20 of Set 3 | fortuna
# Processing Record 21 of Set 3 | coos bay
# Processing Record 22 of Set 3 | talnakh
# Processing Record 23 of Set 3 | poum
# Processing Record 24 of Set 3 | noumea
# Processing Record 25 of Set 3 | kieta
# Processing Record 26 of Set 3 | lebu
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | soure
# Processing Record 29 of Set 3 | yellowknife
# Processing Record 30 of Set 3 | tecoanapa
# Processing Record 31 of Set 3 | grand forks
# Processing Record 32 of Set 3 | ilulissat
# Processing Record 33 of Set 3 | hurup
# Processing Record 34 of Set 3 | bambous virieux
# Processing Record 35 of Set 3 | butaritari
# Processing Record 36 of Set 3 | emerald
# Processing Record 37 of Set 3 | manokwari
# Processing Record 38 of Set 3 | soyo
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | saint-francois
# Processing Record 41 of Set 3 | bluff
# Processing Record 42 of Set 3 | bani walid
# Processing Record 43 of Set 3 | seoul
# Processing Record 44 of Set 3 | port augusta
# Processing Record 45 of Set 3 | moose factory
# Processing Record 46 of Set 3 | dikson
# Processing Record 47 of Set 3 | pangnirtung
# Processing Record 48 of Set 3 | ankang
# Processing Record 49 of Set 3 | lorengau
# Processing Record 50 of Set 3 | yerbogachen
# Processing Record 1 of Set 4 | castro
# Processing Record 2 of Set 4 | longyearbyen
# Processing Record 3 of Set 4 | wamba
# Processing Record 4 of Set 4 | bandrele
# Processing Record 5 of Set 4 | khatanga
# Processing Record 6 of Set 4 | luxor
# Processing Record 7 of Set 4 | corowa
# Processing Record 8 of Set 4 | xining
# Processing Record 9 of Set 4 | lowestoft
# Processing Record 10 of Set 4 | rio gallegos
# Processing Record 11 of Set 4 | gandu
# Processing Record 12 of Set 4 | airai
# Processing Record 13 of Set 4 | anqing
# Processing Record 14 of Set 4 | chapais
# Processing Record 15 of Set 4 | camacha
# Processing Record 16 of Set 4 | norman wells
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | ucluelet
# Processing Record 19 of Set 4 | mar del plata
# Processing Record 20 of Set 4 | sitka
# Processing Record 21 of Set 4 | bireun
# Processing Record 22 of Set 4 | santa cruz cabralia
# Processing Record 23 of Set 4 | jacareacanga
# Processing Record 24 of Set 4 | cherskiy
# Processing Record 25 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 4 | esperance
# Processing Record 27 of Set 4 | akyab
# Processing Record 28 of Set 4 | kununurra
# Processing Record 29 of Set 4 | vila franca do campo
# Processing Record 30 of Set 4 | nantucket
# Processing Record 31 of Set 4 | sioux lookout
# Processing Record 32 of Set 4 | russkaya polyana
# Processing Record 33 of Set 4 | mount isa
# Processing Record 34 of Set 4 | svetlogorsk
# Processing Record 35 of Set 4 | ratnagiri
# Processing Record 36 of Set 4 | samarai
# Processing Record 37 of Set 4 | sept-iles
# Processing Record 38 of Set 4 | ordzhonikidzevskaya
# Processing Record 39 of Set 4 | imbituba
# Processing Record 40 of Set 4 | sidi ali
# Processing Record 41 of Set 4 | tuatapere
# Processing Record 42 of Set 4 | coquimbo
# Processing Record 43 of Set 4 | anadyr
# Processing Record 44 of Set 4 | vanimo
# Processing Record 45 of Set 4 | sur
# Processing Record 46 of Set 4 | bismarck
# Processing Record 47 of Set 4 | denpasar
# Processing Record 48 of Set 4 | lompoc
# Processing Record 49 of Set 4 | hamilton
# Processing Record 50 of Set 4 | hasaki
# Processing Record 1 of Set 5 | chokurdakh
# Processing Record 2 of Set 5 | colac
# Processing Record 3 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 5 | atuona
# Processing Record 5 of Set 5 | port hedland
# Processing Record 6 of Set 5 | pochutla
# Processing Record 7 of Set 5 | kapuskasing
# Processing Record 8 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 5 | srednekolymsk
# Processing Record 10 of Set 5 | busayra
# Processing Record 11 of Set 5 | ostrovnoy
# Processing Record 12 of Set 5 | pisco
# Processing Record 13 of Set 5 | shelburne
# Processing Record 14 of Set 5 | hami
# Processing Record 15 of Set 5 | makakilo city
# Processing Record 16 of Set 5 | naukot
# Processing Record 17 of Set 5 | chegdomyn
# Processing Record 18 of Set 5 | longyan
# Processing Record 19 of Set 5 | hutchinson
# Processing Record 20 of Set 5 | maniitsoq
# Processing Record 21 of Set 5 | bubaque
# Processing Record 22 of Set 5 | thohoyandou
# Processing Record 23 of Set 5 | umm lajj
# Processing Record 24 of Set 5 | thabazimbi
# Processing Record 25 of Set 5 | prince albert
# Processing Record 26 of Set 5 | amla
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | coro
# Processing Record 29 of Set 5 | idlib
# Processing Record 30 of Set 5 | tura
# Processing Record 31 of Set 5 | qaqortoq
# Processing Record 32 of Set 5 | kalmunai
# Processing Record 33 of Set 5 | cameta
# Processing Record 34 of Set 5 | zhigalovo
# Processing Record 35 of Set 5 | saint anthony
# Processing Record 36 of Set 5 | atasu
# Processing Record 37 of Set 5 | guajara-mirim
# City not found. Skipping...
# Processing Record 38 of Set 5 | townsville
# Processing Record 39 of Set 5 | george town
# Processing Record 40 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 5 | portland
# Processing Record 43 of Set 5 | yelizovo
# Processing Record 44 of Set 5 | barao de melgaco
# Processing Record 45 of Set 5 | beloha
# Processing Record 46 of Set 5 | mayumba
# Processing Record 47 of Set 5 | marawi
# Processing Record 48 of Set 5 | suez
# Processing Record 49 of Set 5 | baltasi
# Processing Record 50 of Set 5 | praia
# Processing Record 1 of Set 6 | chimbote
# Processing Record 2 of Set 6 | ewa beach
# Processing Record 3 of Set 6 | voykove
# Processing Record 4 of Set 6 | chute-aux-outardes
# Processing Record 5 of Set 6 | linapacan
# City not found. Skipping...
# Processing Record 6 of Set 6 | henties bay
# Processing Record 7 of Set 6 | nouadhibou
# Processing Record 8 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 9 of Set 6 | hlukhiv
# Processing Record 10 of Set 6 | gamba
# Processing Record 11 of Set 6 | hofn
# Processing Record 12 of Set 6 | saint george
# Processing Record 13 of Set 6 | tuktoyaktuk
# Processing Record 14 of Set 6 | port lincoln
# Processing Record 15 of Set 6 | wuchi
# Processing Record 16 of Set 6 | rafaela
# Processing Record 17 of Set 6 | mawlaik
# Processing Record 18 of Set 6 | burica
# City not found. Skipping...
# Processing Record 19 of Set 6 | dong hoi
# Processing Record 20 of Set 6 | hovd
# Processing Record 21 of Set 6 | jurado
# Processing Record 22 of Set 6 | cidreira
# Processing Record 23 of Set 6 | aguas formosas
# Processing Record 24 of Set 6 | victoria
# Processing Record 25 of Set 6 | bengkulu
# Processing Record 26 of Set 6 | northam
# Processing Record 27 of Set 6 | ariquemes
# Processing Record 28 of Set 6 | kolokani
# Processing Record 29 of Set 6 | lethem
# Processing Record 30 of Set 6 | batagay
# Processing Record 31 of Set 6 | safaga
# Processing Record 32 of Set 6 | port elizabeth
# Processing Record 33 of Set 6 | grand gaube
# Processing Record 34 of Set 6 | abilene
# Processing Record 35 of Set 6 | nanortalik
# Processing Record 36 of Set 6 | aklavik
# Processing Record 37 of Set 6 | cozumel
# Processing Record 38 of Set 6 | itoman
# Processing Record 39 of Set 6 | valparaiso
# Processing Record 40 of Set 6 | katsuura
# Processing Record 41 of Set 6 | pringsewu
# Processing Record 42 of Set 6 | caravelas
# Processing Record 43 of Set 6 | kawalu
# Processing Record 44 of Set 6 | korla
# Processing Record 45 of Set 6 | ulladulla
# Processing Record 46 of Set 6 | tamworth
# Processing Record 47 of Set 6 | tiksi
# Processing Record 48 of Set 6 | honningsvag
# Processing Record 49 of Set 6 | delta
# Processing Record 50 of Set 6 | chicama
# Processing Record 1 of Set 7 | joshimath
# Processing Record 2 of Set 7 | fairbanks
# Processing Record 3 of Set 7 | umm kaddadah
# Processing Record 4 of Set 7 | rio grande
# Processing Record 5 of Set 7 | batman
# Processing Record 6 of Set 7 | veraval
# Processing Record 7 of Set 7 | bontang
# Processing Record 8 of Set 7 | yerofey pavlovich
# Processing Record 9 of Set 7 | port blair
# Processing Record 10 of Set 7 | shizunai
# Processing Record 11 of Set 7 | luderitz
# Processing Record 12 of Set 7 | melchor de mencos
# Processing Record 13 of Set 7 | maldonado
# Processing Record 14 of Set 7 | saskylakh
# Processing Record 15 of Set 7 | nishihara
# Processing Record 16 of Set 7 | sulangan
# Processing Record 17 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 18 of Set 7 | baykit
# Processing Record 19 of Set 7 | motala
# Processing Record 20 of Set 7 | sao miguel
# Processing Record 21 of Set 7 | newport
# Processing Record 22 of Set 7 | dwarka
# Processing Record 23 of Set 7 | kerouane
# Processing Record 24 of Set 7 | solnechnyy
# Processing Record 25 of Set 7 | araquari
# Processing Record 26 of Set 7 | maltahohe
# Processing Record 27 of Set 7 | tezu
# Processing Record 28 of Set 7 | flin flon
# Processing Record 29 of Set 7 | faanui
# Processing Record 30 of Set 7 | leningradskiy
# Processing Record 31 of Set 7 | sao joao da barra
# Processing Record 32 of Set 7 | macas
# Processing Record 33 of Set 7 | bohuslav
# Processing Record 34 of Set 7 | lanivtsi
# Processing Record 35 of Set 7 | edson
# Processing Record 36 of Set 7 | imeni poliny osipenko
# Processing Record 37 of Set 7 | lata
# Processing Record 38 of Set 7 | palora
# Processing Record 39 of Set 7 | egvekinot
# Processing Record 40 of Set 7 | fuerte olimpo
# Processing Record 41 of Set 7 | kenora
# Processing Record 42 of Set 7 | kismayo
# Processing Record 43 of Set 7 | ixtapa
# Processing Record 44 of Set 7 | namatanai
# Processing Record 45 of Set 7 | roald
# Processing Record 46 of Set 7 | manavalakurichi
# Processing Record 47 of Set 7 | kamensk-uralskiy
# Processing Record 48 of Set 7 | alta
# Processing Record 49 of Set 7 | yumen
# Processing Record 50 of Set 7 | olinda
# Processing Record 1 of Set 8 | east london
# Processing Record 2 of Set 8 | karla
# Processing Record 3 of Set 8 | najran
# Processing Record 4 of Set 8 | havelock
# Processing Record 5 of Set 8 | pitimbu
# Processing Record 6 of Set 8 | edd
# Processing Record 7 of Set 8 | hobyo
# Processing Record 8 of Set 8 | tessalit
# Processing Record 9 of Set 8 | zhanaozen
# Processing Record 10 of Set 8 | vestmannaeyjar
# Processing Record 11 of Set 8 | oistins
# Processing Record 12 of Set 8 | camp verde
# Processing Record 13 of Set 8 | buinsk
# Processing Record 14 of Set 8 | maumere
# Processing Record 15 of Set 8 | oga
# Processing Record 16 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 8 | joao pinheiro
# Processing Record 18 of Set 8 | emirdag
# Processing Record 19 of Set 8 | college
# Processing Record 20 of Set 8 | salinas
# Processing Record 21 of Set 8 | yulara
# Processing Record 22 of Set 8 | winnemucca
# Processing Record 23 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 24 of Set 8 | bektemir
# Processing Record 25 of Set 8 | karratha
# Processing Record 26 of Set 8 | road town
# Processing Record 27 of Set 8 | avera
# Processing Record 28 of Set 8 | nelson bay
# Processing Record 29 of Set 8 | joensuu
# Processing Record 30 of Set 8 | oussouye
# Processing Record 31 of Set 8 | adrar
# Processing Record 32 of Set 8 | adre
# Processing Record 33 of Set 8 | yarada
# Processing Record 34 of Set 8 | komsomolskiy
# Processing Record 35 of Set 8 | salta
# Processing Record 36 of Set 8 | weligama
# Processing Record 37 of Set 8 | sorland
# Processing Record 38 of Set 8 | shingu
# Processing Record 39 of Set 8 | de aar
# Processing Record 40 of Set 8 | vinh
# Processing Record 41 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 8 | camargo
# Processing Record 43 of Set 8 | sao joao dos patos
# Processing Record 44 of Set 8 | sangueya
# Processing Record 45 of Set 8 | saravena
# Processing Record 46 of Set 8 | chabahar
# Processing Record 47 of Set 8 | agua prieta
# Processing Record 48 of Set 8 | muisne
# Processing Record 49 of Set 8 | baherden
# Processing Record 50 of Set 8 | mount gambier
# Processing Record 1 of Set 9 | kashi
# Processing Record 2 of Set 9 | beaverlodge
# Processing Record 3 of Set 9 | sabha
# Processing Record 4 of Set 9 | itarema
# Processing Record 5 of Set 9 | ahipara
# Processing Record 6 of Set 9 | villa maria
# Processing Record 7 of Set 9 | tagusao
# Processing Record 8 of Set 9 | sangar
# Processing Record 9 of Set 9 | saldanha
# Processing Record 10 of Set 9 | dongsheng
# Processing Record 11 of Set 9 | isangel
# Processing Record 12 of Set 9 | palia kalan
# Processing Record 13 of Set 9 | atchison
# Processing Record 14 of Set 9 | pacific grove
# Processing Record 15 of Set 9 | imeni babushkina
# Processing Record 16 of Set 9 | geraldton
# Processing Record 17 of Set 9 | aktau
# Processing Record 18 of Set 9 | zhangye
# Processing Record 19 of Set 9 | thinadhoo
# Processing Record 20 of Set 9 | cockburn town
# Processing Record 21 of Set 9 | viedma
# Processing Record 22 of Set 9 | vangaindrano
# Processing Record 23 of Set 9 | maningrida
# Processing Record 24 of Set 9 | ponta delgada
# Processing Record 25 of Set 9 | lashio
# Processing Record 26 of Set 9 | sovetskiy
# Processing Record 27 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 9 | svetlaya
# Processing Record 29 of Set 9 | zaria
# Processing Record 30 of Set 9 | shupiyan
# Processing Record 31 of Set 9 | storforshei
# Processing Record 32 of Set 9 | manoel urbano
# Processing Record 33 of Set 9 | ngunguru
# Processing Record 34 of Set 9 | elat
# Processing Record 35 of Set 9 | mitsamiouli
# Processing Record 36 of Set 9 | touros
# Processing Record 37 of Set 9 | jiayuguan
# Processing Record 38 of Set 9 | flinders
# Processing Record 39 of Set 9 | lasa
# Processing Record 40 of Set 9 | zunyi
# Processing Record 41 of Set 9 | borlange
# City not found. Skipping...
# Processing Record 42 of Set 9 | simpang
# Processing Record 43 of Set 9 | kamareddi
# Processing Record 44 of Set 9 | hwange
# Processing Record 45 of Set 9 | conde
# Processing Record 46 of Set 9 | astana
# Processing Record 47 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 9 | ayan
# Processing Record 49 of Set 9 | bonfim
# Processing Record 50 of Set 9 | monroe
# Processing Record 1 of Set 10 | andenes
# Processing Record 2 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 10 | ashland
# Processing Record 4 of Set 10 | kaitangata
# Processing Record 5 of Set 10 | lipin bor
# Processing Record 6 of Set 10 | chernyshevskiy
# Processing Record 7 of Set 10 | bathsheba
# Processing Record 8 of Set 10 | torbat-e jam
# Processing Record 9 of Set 10 | narsaq
# Processing Record 10 of Set 10 | wagar
# Processing Record 11 of Set 10 | tucurui
# Processing Record 12 of Set 10 | launceston
# Processing Record 13 of Set 10 | goderich
# Processing Record 14 of Set 10 | broken hill
# Processing Record 15 of Set 10 | polewali
# Processing Record 16 of Set 10 | cabedelo
# Processing Record 17 of Set 10 | san patricio
# Processing Record 18 of Set 10 | antipolo
# Processing Record 19 of Set 10 | aykhal
# Processing Record 20 of Set 10 | maple creek
# Processing Record 21 of Set 10 | agva
# City not found. Skipping...
# Processing Record 22 of Set 10 | charters towers
# Processing Record 23 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 24 of Set 10 | tyrma
# Processing Record 25 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 26 of Set 10 | poltava
# Processing Record 27 of Set 10 | maturin
# Processing Record 28 of Set 10 | kavaratti
# Processing Record 29 of Set 10 | padang
# Processing Record 30 of Set 10 | zarand
# Processing Record 31 of Set 10 | sampit
# Processing Record 32 of Set 10 | kapit
# Processing Record 33 of Set 10 | asfi
# Processing Record 34 of Set 10 | skowhegan
# Processing Record 35 of Set 10 | guna
# Processing Record 36 of Set 10 | kemin
# Processing Record 37 of Set 10 | kolda
# Processing Record 38 of Set 10 | lagos
# Processing Record 39 of Set 10 | evensk
# Processing Record 40 of Set 10 | teguise
# Processing Record 41 of Set 10 | clyde river
# Processing Record 42 of Set 10 | narragansett
# Processing Record 43 of Set 10 | nizamabad
# Processing Record 44 of Set 10 | tutin
# Processing Record 45 of Set 10 | tucuman
# Processing Record 46 of Set 10 | acajutla
# Processing Record 47 of Set 10 | desna
# Processing Record 48 of Set 10 | tarabuco
# Processing Record 49 of Set 10 | zambezi
# Processing Record 50 of Set 10 | bemidji
# Processing Record 1 of Set 11 | rawson
# Processing Record 2 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 11 | boa vista
# Processing Record 4 of Set 11 | maloy
# Processing Record 5 of Set 11 | catamarca
# Processing Record 6 of Set 11 | constitucion
# Processing Record 7 of Set 11 | margate
# Processing Record 8 of Set 11 | kaeo
# Processing Record 9 of Set 11 | penzance
# Processing Record 10 of Set 11 | guerrero negro
# Processing Record 11 of Set 11 | xuddur
# Processing Record 12 of Set 11 | buenos aires
# Processing Record 13 of Set 11 | namtsy
# Processing Record 14 of Set 11 | dongfeng
# Processing Record 15 of Set 11 | kamenka
# Processing Record 16 of Set 11 | kalga
# Processing Record 17 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 18 of Set 11 | kavieng
# Processing Record 19 of Set 11 | kidal
# Processing Record 20 of Set 11 | sharkan
# Processing Record 21 of Set 11 | atikokan
# Processing Record 22 of Set 11 | ferrol
# Processing Record 23 of Set 11 | eyl
# Processing Record 24 of Set 11 | san cristobal
# Processing Record 25 of Set 11 | sabang
# Processing Record 26 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 11 | chazuta
# Processing Record 28 of Set 11 | olafsvik
# Processing Record 29 of Set 11 | statesboro
# Processing Record 30 of Set 11 | pecos
# Processing Record 31 of Set 11 | tabas
# Processing Record 32 of Set 11 | copiapo
# Processing Record 33 of Set 11 | partapur
# Processing Record 34 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 35 of Set 11 | floro
# Processing Record 36 of Set 11 | gazanjyk
# Processing Record 37 of Set 11 | ambanja
# Processing Record 38 of Set 11 | grindavik
# Processing Record 39 of Set 11 | verkhoyansk
# Processing Record 40 of Set 11 | talara
# Processing Record 41 of Set 11 | chara
# Processing Record 42 of Set 11 | dunedin
# Processing Record 43 of Set 11 | san carlos de bariloche
# Processing Record 44 of Set 11 | marfino
# Processing Record 45 of Set 11 | marienburg
# Processing Record 46 of Set 11 | aragats
# Processing Record 47 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 48 of Set 11 | hatillo
# Processing Record 49 of Set 11 | itaituba
# Processing Record 50 of Set 11 | caconda
# Processing Record 1 of Set 12 | luzhou
# Processing Record 2 of Set 12 | ayorou
# Processing Record 3 of Set 12 | siverskiy
# Processing Record 4 of Set 12 | inhambane
# Processing Record 5 of Set 12 | morogoro
# Processing Record 6 of Set 12 | puerto leguizamo
# Processing Record 7 of Set 12 | benoy
# Processing Record 8 of Set 12 | guaranesia
# Processing Record 9 of Set 12 | riyadh
# Processing Record 10 of Set 12 | vievis
# Processing Record 11 of Set 12 | atar
# Processing Record 12 of Set 12 | fort collins
# Processing Record 13 of Set 12 | kostino
# Processing Record 14 of Set 12 | marica
# Processing Record 15 of Set 12 | kendari
# Processing Record 16 of Set 12 | harnai
# Processing Record 17 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 12 | kailua
# Processing Record 19 of Set 12 | narrabri
# Processing Record 20 of Set 12 | half moon bay
# Processing Record 21 of Set 12 | fuling
# Processing Record 22 of Set 12 | kasiri
# Processing Record 23 of Set 12 | kampong thum
# Processing Record 24 of Set 12 | kalomo
# City not found. Skipping...
# Processing Record 25 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 12 | takapau
# Processing Record 28 of Set 12 | comodoro rivadavia
# Processing Record 29 of Set 12 | muros
# Processing Record 30 of Set 12 | puerto narino
# Processing Record 31 of Set 12 | udachnyy
# Processing Record 32 of Set 12 | mao
# Processing Record 33 of Set 12 | sola
# Processing Record 34 of Set 12 | leshan
# Processing Record 35 of Set 12 | vuktyl
# Processing Record 36 of Set 12 | catalina
# Processing Record 37 of Set 12 | alyangula
# Processing Record 38 of Set 12 | batagay-alyta
# Processing Record 39 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 40 of Set 12 | basco
# Processing Record 41 of Set 12 | tommot
# Processing Record 42 of Set 12 | coari
# Processing Record 43 of Set 12 | pimentel
# Processing Record 44 of Set 12 | vardo
# Processing Record 45 of Set 12 | balsas
# Processing Record 46 of Set 12 | bilma
# Processing Record 47 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 48 of Set 12 | vao
# Processing Record 49 of Set 12 | antalaha
# Processing Record 50 of Set 12 | north branch
# Processing Record 1 of Set 13 | buala
# Processing Record 2 of Set 13 | wanning
# Processing Record 3 of Set 13 | mae sai
# Processing Record 4 of Set 13 | taveta
# Processing Record 5 of Set 13 | bilibino
# Processing Record 6 of Set 13 | slave lake
# Processing Record 7 of Set 13 | sydney
# Processing Record 8 of Set 13 | whitianga
# Processing Record 9 of Set 13 | kruisfontein
# Processing Record 10 of Set 13 | khudumelapye
# Processing Record 11 of Set 13 | salina cruz
# Processing Record 12 of Set 13 | ahuimanu
# Processing Record 13 of Set 13 | nuuk
# Processing Record 14 of Set 13 | lazaro cardenas
# Processing Record 15 of Set 13 | sedam
# Processing Record 16 of Set 13 | tabou
# Processing Record 17 of Set 13 | stornoway
# Processing Record 18 of Set 13 | coahuayana
# Processing Record 19 of Set 13 | douglas
# Processing Record 20 of Set 13 | koygorodok
# Processing Record 21 of Set 13 | sibolga
# Processing Record 22 of Set 13 | golden
# Processing Record 23 of Set 13 | loa janan
# Processing Record 24 of Set 13 | naze
# Processing Record 25 of Set 13 | sungairaya
# Processing Record 26 of Set 13 | otradnoye
# Processing Record 27 of Set 13 | mogadishu
# Processing Record 28 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 13 | kuloy
# Processing Record 30 of Set 13 | les cayes
# Processing Record 31 of Set 13 | urumqi
# Processing Record 32 of Set 13 | naryan-mar
# Processing Record 33 of Set 13 | el alto
# Processing Record 34 of Set 13 | avanigadda
# Processing Record 35 of Set 13 | salaverry
# Processing Record 36 of Set 13 | port-gentil
# Processing Record 37 of Set 13 | huarmey
# Processing Record 38 of Set 13 | ayagoz
# Processing Record 39 of Set 13 | mehran
# Processing Record 40 of Set 13 | abay
# Processing Record 41 of Set 13 | berlevag
# Processing Record 42 of Set 13 | saint-pierre
# Processing Record 43 of Set 13 | mazamet
# Processing Record 44 of Set 13 | arenapolis
# Processing Record 45 of Set 13 | omboue
# Processing Record 46 of Set 13 | acapulco
# Processing Record 47 of Set 13 | sirjan
# Processing Record 48 of Set 13 | muswellbrook
# Processing Record 49 of Set 13 | hervey bay
# Processing Record 50 of Set 13 | canaries
# Processing Record 1 of Set 14 | shache
# Processing Record 2 of Set 14 | taoudenni
# Processing Record 3 of Set 14 | broome
# Processing Record 4 of Set 14 | pinsk
# Processing Record 5 of Set 14 | soyaniquilpan
# Processing Record 6 of Set 14 | andarab
# City not found. Skipping...
# Processing Record 7 of Set 14 | limon
# Processing Record 8 of Set 14 | severobaykalsk
# Processing Record 9 of Set 14 | laguna
# Processing Record 10 of Set 14 | tabuk
# Processing Record 11 of Set 14 | chimoio
# Processing Record 12 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 14 | maryborough
# Processing Record 14 of Set 14 | diu
# Processing Record 15 of Set 14 | salinopolis
# Processing Record 16 of Set 14 | san ramon de la nueva oran
# Processing Record 17 of Set 14 | opuwo
# Processing Record 18 of Set 14 | halifax
# Processing Record 19 of Set 14 | srivardhan
# Processing Record 20 of Set 14 | ketchikan
# Processing Record 21 of Set 14 | boende
# Processing Record 22 of Set 14 | mayo
# Processing Record 23 of Set 14 | port hardy
# Processing Record 24 of Set 14 | chaa-khol
# City not found. Skipping...
# Processing Record 25 of Set 14 | sao filipe
# Processing Record 26 of Set 14 | rincon
# Processing Record 27 of Set 14 | guane
# Processing Record 28 of Set 14 | griffith
# Processing Record 29 of Set 14 | ust-nera
# Processing Record 30 of Set 14 | ranau
# Processing Record 31 of Set 14 | eirunepe
# Processing Record 32 of Set 14 | bay city
# Processing Record 33 of Set 14 | malia
# Processing Record 34 of Set 14 | shubarkuduk
# Processing Record 35 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 14 | tautira
# Processing Record 37 of Set 14 | hit
# Processing Record 38 of Set 14 | salisbury
# Processing Record 39 of Set 14 | calama
# Processing Record 40 of Set 14 | asau
# Processing Record 41 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 42 of Set 14 | killybegs
# Processing Record 43 of Set 14 | coihaique
# Processing Record 44 of Set 14 | kjopsvik
# Processing Record 45 of Set 14 | chandrakona
# Processing Record 46 of Set 14 | hambantota
# Processing Record 47 of Set 14 | atambua
# Processing Record 48 of Set 14 | kano
# Processing Record 49 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 14 | lamu
# Processing Record 1 of Set 15 | codrington
# Processing Record 2 of Set 15 | marsh harbour
# Processing Record 3 of Set 15 | mana
# Processing Record 4 of Set 15 | capreol
# Processing Record 5 of Set 15 | taltal
# Processing Record 6 of Set 15 | gillette
# Processing Record 7 of Set 15 | yate
# Processing Record 8 of Set 15 | tual
# Processing Record 9 of Set 15 | gravelbourg
# Processing Record 10 of Set 15 | starobaltachevo
# Processing Record 11 of Set 15 | aripuana
# Processing Record 12 of Set 15 | high level
# Processing Record 13 of Set 15 | westport
# Processing Record 14 of Set 15 | udimskiy
# Processing Record 15 of Set 15 | lichinga
# Processing Record 16 of Set 15 | priiskovyy
# Processing Record 17 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 15 | los llanos de aridane
# Processing Record 19 of Set 15 | erenhot
# Processing Record 20 of Set 15 | van
# Processing Record 21 of Set 15 | talcahuano
# Processing Record 22 of Set 15 | labrea
# Processing Record 23 of Set 15 | kishtwar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 673

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Bethel      US  41.3712  -73.4140     79.11        65           0
# 1    Jamestown      US  42.0970  -79.2353     69.39        55           0
# 2    Frameries      BE  50.4058    3.8960     54.57        94          42
# 3      Hualmay      PE -11.0964  -77.6139     60.53        82          59
# 4  Mykolayivka      UA  47.5414   30.7561     66.63        55           2
# 5     Tasiilaq      GL  65.6145  -37.6368     46.56        77         100
# 6    Busselton      AU -33.6500  115.3333     62.19        71          51
# 7     Mabaruma      GY   8.2000  -59.7833     73.22        98          60
# 8  New Norfolk      AU -42.7826  147.0587     49.71        61         100
# 9       Hobart      AU -42.8794  147.3294     50.05        89          75
#
#    Wind Speed Current Description
# 0        4.61           clear sky
# 1        8.05           clear sky
# 2        5.75    scattered clouds
# 3       14.16       broken clouds
# 4        6.38           clear sky
# 5       10.20     overcast clouds
# 6       12.88       broken clouds
# 7        2.04       broken clouds
# 8        5.08     overcast clouds
# 9        5.75       broken clouds

# %%
# Create the output file (CSV).
city_data_df.to_csv("WeatherPy_Database.csv")
